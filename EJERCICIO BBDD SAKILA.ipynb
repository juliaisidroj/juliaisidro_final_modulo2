# %% [markdown]
# 2. BASE DE DATOS SAKILA

# %% [markdown]
# 1- Copiamos y creamos la base de datos en MySql (copia y pega de los ficheros sakila que tenemos en el repositorio)
# 2. Creamos un esquema en MySql para facilitarnos las consultas
